# %% [markdown]
# # **Trabajo final**
#
# ACUÑA URIARTE MARIA JOSE
#
# ULATE GARCIA ROY ALEJANDRO
#
# ALVAREZ ULATE ANGIE DANIELA
#
# INESTROZA GARCIA JOSTIN

# %%
#importar la libreria Pandas 
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# Vamos a prodecer a realizar la carga de los datos que se van a analizar en una estructuctura del tipo Dataframe

# %%
data_russia_losses_equipment = pd.read_csv('russia_losses_equipment.csv')
data_russia_losses_equipment
# Out:
#           date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 0   2022-02-25    2        10           7    80   516               49    4
# 1   2022-02-26    3        27          26   146   706               49    4
# 2   2022-02-27    4        27          26   150   706               50    4
# 3   2022-02-28    5        29          29   150   816               74   21
# 4   2022-03-01    6        29          29   198   846               77   24
# 5   2022-03-02    7        30          31   211   862               85   40
# 6   2022-03-03    8        30          31   217   900               90   42
# 7   2022-03-04    9        33          37   251   939              105   50
# 8   2022-03-05   10        39          40   269   945              105   50
# 9   2022-03-06   11        44          48   285   985              109   50
# 10  2022-03-07   12        46          68   290   999              117   50
# ...

# %%
data_russia_losses_personnel= pd.read_csv('russia_losses_personnel.csv')
data_russia_losses_personnel
# Out:
#           date  day  personnel personnel*  POW
# 0   2022-02-25    2       2800      about    0
# 1   2022-02-26    3       4300      about    0
# 2   2022-02-27    4       4500      about    0
# 3   2022-02-28    5       5300      about    0
# 4   2022-03-01    6       5710      about  200
# 5   2022-03-02    7       5840      about  200
# 6   2022-03-03    8       9000      about  200
# 7   2022-03-04    9       9166      about  200
# 8   2022-03-05   10      10000      about  216
# 9   2022-03-06   11      11000      about  232
# 10  2022-03-07   12      11000       more  259
# 11  2022-03-08   13      12000      about  284
# 12  2022-03-09   14      12000      about  360
# 13  2022-03-10   15      12000       more  371
# 14  2022-03-11   16      12000       more  389
# 15  2022-03-12   17      12000       more  389
# 16  2022-03-13   18      12000       more  389
# 17  2022-03-14   19      12000       more  389
# 18  2022-03-15   20      13500      about  389
# ...

# %%
#vamos a visualizar los tipos de datos que posee nuestro dataframe
data_russia_losses_equipment.dtypes
# Out:
# date                      object
# day                        int64
# aircraft                   int64
# helicopter                 int64
# tank                       int64
# APC                        int64
# field artillery            int64
# MRL                        int64
# military auto              int64
# fuel tank                  int64
# drone                      int64
# naval ship                 int64
# anti-aircraft warfare      int64
# special equipment        float64
# mobile SRBM system       float64
# dtype: object

# %%
data_russia_losses_personnel.dtypes
# Out:
# date          object
# day            int64
# personnel      int64
# personnel*    object
# POW            int64
# dtype: object

# %%
#visulizar la cantidad de filas y columnas que tiene nuestro dataframe
print('El dataframe posee {} filas y {} columnas '.format(data_russia_losses_equipment.shape[0],data_russia_losses_equipment.shape[1]))
# Out:
# El dataframe posee 39 filas y 15 columnas

# %%
print('El dataframe posee {} filas y {} columnas '.format(data_russia_losses_personnel.shape[0],data_russia_losses_personnel.shape[1]))
# Out:
# El dataframe posee 39 filas y 5 columnas

# %%
# Vamos a ver que columnas tienen valores nulos
data_russia_losses_equipment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   39 non-null     object
#  1   day                    39 non-null     int64
#  2   aircraft               39 non-null     int64
#  3   helicopter             39 non-null     int64
#  4   tank                   39 non-null     int64
#  5   APC                    39 non-null     int64
#  6   field artillery        39 non-null     int64
#  7   MRL                    39 non-null     int64
#  8   military auto          39 non-null     int64
#  9   fuel tank              39 non-null     int64
#  10  drone                  39 non-null     int64
#  11  naval ship             39 non-null     int64
#  12  anti-aircraft warfare  39 non-null     int64
#  13  special equipment      20 non-null     float64
#  14  mobile SRBM system     10 non-null     float64
# ...

# %%
data_russia_losses_personnel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        39 non-null     object
#  1   day         39 non-null     int64
#  2   personnel   39 non-null     int64
#  3   personnel*  39 non-null     object
#  4   POW         39 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 1.6+ KB

# %%
#vamos a rellenar la columna de special equipment con la media de los datos
#vamos a obtener la media de los datos de special equipment  
data_russia_losses_equipment['special equipment'].mean()
# Out:
# 17.65

# %%
 data_russia_losses_equipment['mobile SRBM system'].mean()
# Out:
# 3.8

# %%
#rellenamos las columnas con el valor de la media
data_russia_losses_equipment['special equipment'] = data_russia_losses_equipment['special equipment'].fillna(data_russia_losses_equipment['special equipment'].mean())

# %%
data_russia_losses_equipment['mobile SRBM system'] = data_russia_losses_equipment['mobile SRBM system'].fillna(data_russia_losses_equipment['mobile SRBM system'].mean())

# %%
#verificamos que ya no existen nulos
data_russia_losses_equipment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   39 non-null     object
#  1   day                    39 non-null     int64
#  2   aircraft               39 non-null     int64
#  3   helicopter             39 non-null     int64
#  4   tank                   39 non-null     int64
#  5   APC                    39 non-null     int64
#  6   field artillery        39 non-null     int64
#  7   MRL                    39 non-null     int64
#  8   military auto          39 non-null     int64
#  9   fuel tank              39 non-null     int64
#  10  drone                  39 non-null     int64
#  11  naval ship             39 non-null     int64
#  12  anti-aircraft warfare  39 non-null     int64
#  13  special equipment      39 non-null     float64
#  14  mobile SRBM system     39 non-null     float64
# ...

# %%
# Vamos a unir las dos dataframe
#datas_russia = pd.concat([data_russia_losses_equipment, data_russia_losses_personnel],axis=1)
datas_russia = data_russia_losses_equipment.merge(data_russia_losses_personnel,on=('date','day') ,how="left")
datas_russia
# Out:
#           date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 0   2022-02-25    2        10           7    80   516               49    4
# 1   2022-02-26    3        27          26   146   706               49    4
# 2   2022-02-27    4        27          26   150   706               50    4
# 3   2022-02-28    5        29          29   150   816               74   21
# 4   2022-03-01    6        29          29   198   846               77   24
# 5   2022-03-02    7        30          31   211   862               85   40
# 6   2022-03-03    8        30          31   217   900               90   42
# 7   2022-03-04    9        33          37   251   939              105   50
# 8   2022-03-05   10        39          40   269   945              105   50
# 9   2022-03-06   11        44          48   285   985              109   50
# 10  2022-03-07   12        46          68   290   999              117   50
# ...

# %%
#visualizar los tipos de datos de cada columna de nuestro dataframe
datas_russia.dtypes
# Out:
# date                      object
# day                        int64
# aircraft                   int64
# helicopter                 int64
# tank                       int64
# APC                        int64
# field artillery            int64
# MRL                        int64
# military auto              int64
# fuel tank                  int64
# drone                      int64
# naval ship                 int64
# anti-aircraft warfare      int64
# special equipment        float64
# mobile SRBM system       float64
# personnel                  int64
# personnel*                object
# POW                        int64
# dtype: object

# %%
#visulizar la cantidad de filas y columnas que tiene nuestro dataframe
print('El dataframe posee {} filas y {} columnas '.format(datas_russia.shape[0],datas_russia.shape[1]))
# Out:
# El dataframe posee 39 filas y 18 columnas

# %%
#Ver la columnas que componen nuestro dataframe
datas_russia.columns
# Out:
# Index(['date', 'day', 'aircraft', 'helicopter', 'tank', 'APC',
#        'field artillery', 'MRL', 'military auto', 'fuel tank', 'drone',
#        'naval ship', 'anti-aircraft warfare', 'special equipment',
#        'mobile SRBM system', 'personnel', 'personnel*', 'POW'],
#       dtype='object')

# %%
# Vamos a ver que columnas tienen valores nulos
datas_russia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 0 to 38
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   39 non-null     object
#  1   day                    39 non-null     int64
#  2   aircraft               39 non-null     int64
#  3   helicopter             39 non-null     int64
#  4   tank                   39 non-null     int64
#  5   APC                    39 non-null     int64
#  6   field artillery        39 non-null     int64
#  7   MRL                    39 non-null     int64
#  8   military auto          39 non-null     int64
#  9   fuel tank              39 non-null     int64
#  10  drone                  39 non-null     int64
#  11  naval ship             39 non-null     int64
#  12  anti-aircraft warfare  39 non-null     int64
#  13  special equipment      39 non-null     float64
#  14  mobile SRBM system     39 non-null     float64
# ...

# %%
#visuliza la cabeza del dataframe
datas_russia.head()
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  2022-02-25    2        10           7    80  516               49    4
# 1  2022-02-26    3        27          26   146  706               49    4
# 2  2022-02-27    4        27          26   150  706               50    4
# 3  2022-02-28    5        29          29   150  816               74   21
# 4  2022-03-01    6        29          29   198  846               77   24
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0            100         60      0           2                      0
# 1            130         60      2           2                      0
# 2            130         60      2           2                      0
# 3            291         60      3           2                      5
# 4            305         60      3           2                      7
#
#    special equipment  mobile SRBM system  personnel personnel*  POW
# ...

# %%
#visuliza la cola del dataframe
datas_russia.tail()
# Out:
#           date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 34  2022-03-31   36       135         131   614  1735              311   96
# 35  2022-04-01   37       143         131   625  1751              316   96
# 36  2022-04-02   38       143         134   631  1776              317  100
# 37  2022-04-03   39       143         134   644  1830              325  105
# 38  2022-04-04   40       147         134   647  1844              330  107
#
#     military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 34           1201         75     83           7                     54
# 35           1220         76     85           7                     54
# 36           1236         76     87           7                     54
# 37           1249         76     89           7                     54
# 38           1273         76     91           7                     54
#
#     special equipment  mobile SRBM system  personnel personnel*  POW
# ...

# %%
#Visualizar un pequeño análisis estadistico
datas_russia.describe()
# Out:
#              day    aircraft  helicopter        tank          APC  \
# count  39.000000   39.000000   39.000000   39.000000    39.000000
# mean   21.000000   80.538462   90.615385  412.076923  1308.410256
# std    11.401754   41.035188   40.404283  164.547767   369.930557
# min     2.000000   10.000000    7.000000   80.000000   516.000000
# 25%    11.500000   45.000000   58.000000  287.500000   992.000000
# 50%    21.000000   84.000000  108.000000  430.000000  1375.000000
# 75%    30.500000  116.000000  126.000000  568.000000  1632.500000
# max    40.000000  147.000000  134.000000  647.000000  1844.000000
#
#        field artillery         MRL  military auto  fuel tank      drone  \
# count        39.000000   39.000000      39.000000  39.000000  39.000000
# mean        190.717949   65.743590     753.051282  64.871795  29.051282
# std          94.263614   27.984693     366.854406   6.712829  31.521045
# min          49.000000    4.000000     100.000000  60.000000   0.000000
# ...

# %% [markdown]
# # **Vamos a preguntarle a nuestra dataframe**

# %%
#Cual fue el maximo numero de autos militares que se utilizaron 
datas_russia["military auto"].max()
# Out:
# 1273

# %%
#Cual fue la minima cantidad de artilleria de campo que fue utilizada
datas_russia["field artillery"].min()
# Out:
# 49

# %%
#cual fue la media de la cantidad de personal utilizado
datas_russia["personnel"].mean()
# Out:
# 12787.589743589744

# %%
#queremos saber cual fue el numero maximo de personal utilizado
datas_russia["personnel"].max()
# Out:
# 18300

# %%
#queremos saber informacion de la fecha inicial del dataframe
datas_russia[datas_russia["date"] == datas_russia["date"].min()]
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  2022-02-25    2        10           7    80  516               49    4
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0            100         60      0           2                      0
#
#    special equipment  mobile SRBM system  personnel personnel*  POW
# 0              17.65                 3.8       2800      about    0

# %%
#se desea conocer toda la informacion del numero maximo de personal utilizado
datas_russia[datas_russia["personnel"] ==datas_russia["personnel"].max()]
# Out:
#           date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 38  2022-04-04   40       147         134   647  1844              330  107
#
#     military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 38           1273         76     91           7                     54
#
#     special equipment  mobile SRBM system  personnel personnel*  POW
# 38               25.0                 4.0      18300      about  460

# %%
#cual es la cantidad minima que se utilizo de personnel,naval ship, fuel tank y helicopter
datas_russia["personnel"].min(),datas_russia["naval ship"].min(),datas_russia["fuel tank"].min(),datas_russia["helicopter"].min()
# Out:
# (2800, 2, 60, 7)

# %%
# Queremos saber cuantos tank se utilizaron 
datas_russia["tank"].sum()
# Out:
# 16071

# %%
# Queremos saber cuantos fuel tank se utilizaron 
datas_russia["fuel tank"].sum()
# Out:
# 2530

# %%
# Queremos saber cuantos drone se utilizaron 
datas_russia["drone"].sum()
# Out:
# 1133

# %%
# Queremos saber cuantos helicopter se utilizaron 
datas_russia["helicopter"].sum()
# Out:
# 3534

# %%
# Queremos saber cuantos military auto se utilizaron 
datas_russia["military auto"].sum()
# Out:
# 29369

# %%
# Queremos saber cuantos special equipment se utilizaron 
datas_russia["special equipment"].sum()
# Out:
# 688.3499999999999

# %% [markdown]
# # **GRAFIQUEMOS**

# %%
#Vamos a gráficar los helicopteros que se utilzaron en los dias respectivos de batalla 
datas_russia.groupby("day")["helicopter"].sum().plot(kind = "bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c26d7109fde3> in <module>()
#       1 #Vamos a gráficar los helicopteros que se utilzaron en los dias respectivos de batalla
# ----> 2 datas_russia.groupby("day")["helicopter"].sum().plot(kind = "bar")
#
# NameError: name 'datas_russia' is not defined

# %%
#Vamos a graficar la cantidad de drones
datas_russia["drone"].value_counts().plot(kind= "barh",color= ["r","g","b"])

# %%
#Vamos a graficar la cantidad de military promedio con respecto a la fecha
datas_russia.groupby("date")["military auto"].sum().plot(kind= "barh",color= ["r","g","b"])

# %%
#Grafica de la cantidad de naval ship o barcos de guerra que se Destruidos durante las diferentes fechas de combate 
datas_russia.groupby("day")["naval ship"].sum().plot(kind = "bar")

# %%
#Grafica de las aeronaves que se Destruidos en los dias respectivos de batalla 
datas_russia.groupby("day")["aircraft"].sum().plot(kind = "bar")

# %%
#graficar la cantidad de field artillery Destruidos por dia 
datas_russia.groupby("day")['field artillery'].sum().plot(kind = "bar")

# %%
#graficar la cantidad de day Destruidos por dia 
datas_russia.groupby("day")["helicopter"].sum().plot(kind = "bar")

# %%
 #ver el combustible utilizado en promedio por dia
datas_russia.groupby("day")["fuel tank"].sum().plot(kind= "barh",color= ["r","g","b"])

# %%
# COmportamiento de los numeros de equipos destruidos diariamente
datas_russia_personas=["aircraft","helicopter","tank","APC","field artillery","MRL","military auto","fuel tank","drone","naval ship","anti-aircraft warfare","special equipment"]

# %%
px.pie(datas_russia[datas_russia_personas],values=datas_russia[datas_russia_personas].sum(),names=datas_russia_personas)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Conclusiones

# %%
print("El número de equipos destruidos hasta la fecha son")
print("-"*100)
for i in datas_russia_personas:
    print(i,datas_russia[i].max())
    
print("-"*100)
# Out:
# El número de equipos destruidos hasta la fecha son
# ----------------------------------------------------------------------------------------------------
# aircraft 147
# helicopter 134
# tank 647
# APC 1844
# field artillery 330
# MRL 107
# military auto 1273
# fuel tank 76
# drone 91
# naval ship 7
# anti-aircraft warfare 54
# special equipment 25.0
# ----------------------------------------------------------------------------------------------------
